# %% [markdown]
# ### **Python 03**
# Strings

# %%
# type() Function
num1 = 33
num2 =33.2
print(type(num1))
print(type(num2))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print( 3 // 2 ) # Floor Division:
print( 3 ** 2 ) # Exponent:
# Out:
# 1
# 9

# %%
# Functions 
print(abs(-3))
print(round(5.81,1))
# Out:
# 3
# 5.8

# %%
num1 = int(3)
num2 = int(2)

print(num1 + num2)
# Out:
# 5

# %% [markdown]
# ### Python 04
# Lists, Tuples, and Sets

# %%
# list
course = ['ELC','Maths','IP'] 
newCourse = ['DBMS','SE']
print(course[1])
print(course[-1]) #last iteam

print(course[0:]) #Slicing
print(course[:2])

course.append('OOPS') 

#course.append(newCourse)
print(course)

course.extend(newCourse) 
print(course)

course.insert(1,'ADA')
print(course)
# Out:
# Maths
# IP
# ['ELC', 'Maths', 'IP']
# ['ELC', 'Maths']
# ['ELC', 'Maths', 'IP', 'OOPS']
# ['ELC', 'Maths', 'IP', 'OOPS', 'DBMS', 'SE']
# ['ELC', 'ADA', 'Maths', 'IP', 'OOPS', 'DBMS', 'SE']

# %%
course = ['ELC','Maths','IP']
course.remove('Maths')
poped = course.pop()

print(course)
print(poped)
# Out:
# ['ELC']
# IP

# %%
course = ['ELC','Maths','IP']
sortedList = sorted(course) # not sort Orignal List, just output Sorted list
print(sortedList)

course.sort() # sort Orignal List 
print(course)

course.sort(reverse=True) #desc order
print(course)
# Out:
# ['ELC', 'IP', 'Maths']
# ['ELC', 'IP', 'Maths']
# ['Maths', 'IP', 'ELC']

# %%
course = ['ELC','Maths','IP','DBMS','SE']

print(course.index('Maths'))
print('Maths' in course)
# Out:
# 1
# True

# %%
# for loop 
courses = ['ELC','Maths','IP','DBMS','SE']
 
for course in courses:
  print(course)

for index, course in enumerate(courses):
  print(index,course)
# Out:
# ELC
# Maths
# IP
# DBMS
# SE
# 0 ELC
# 1 Maths
# 2 IP
# 3 DBMS
# 4 SE

# %%
# Join and split fun
courses = ['ELC','Maths','IP','DBMS','SE']

coursesStr = '-'.join(courses)

newList = coursesStr.split('-')

print(courses)
print(coursesStr)
print(newList)
# Out:
# ['ELC', 'Maths', 'IP', 'DBMS', 'SE']
# ELC-Maths-IP-DBMS-SE
# ['ELC', 'Maths', 'IP', 'DBMS', 'SE']

# %%
# Tuples (can't Modify) - Inmutable
courses = ('ELC','Maths','IP','DBMS','SE')

# %%
#      Sets - No Duplicate Values
#           - unlike List/Tuples, Sets Don't Care about Order
cseCourses = {'ELC','Maths','IP','DBMS','SE'} 
elcCourses = {'OOPS','ELC','DBMS'}

print(cseCourses.intersection(elcCourses))
print(cseCourses.difference(elcCourses))
print(cseCourses.union(elcCourses))
# Out:
# {'ELC', 'DBMS'}
# {'SE', 'Maths', 'IP'}
# {'SE', 'Maths', 'IP', 'ELC', 'DBMS', 'OOPS'}

# %%
	
# Empty Lists
empty_list = []
empty_list = list()

# Empty Tuples
empty_tuple = ()
empty_tuple = tuple()

# Empty Sets
empty_set = {} # This isn't right! It's a dict
empty_set = set()

# %% [markdown]
# ### **Python 05**
# Dictionaries - Working with Key-Value Pairs

# %%
#Dictionary
student = {'name':'Shaurya', 'Age':25, 'course':['maths','se']}

print(student['name']) #access through key
print(student.get('name'))

# print(student['phone']) #this throw error
print(student.get('phone','NOT FOUND')) #avoid above error

student['phone']='2221-22111' #add new element
student.update({'name':'Jane','age':26,'phone':'222222'}) # add more elements at one time

del student['Age'] #del age from dictionary
age = student.pop('age') # another way
print(student)
print(age)
# Out:
# Shaurya
# Shaurya
# NOT FOUND
# {'name': 'Jane', 'course': ['maths', 'se'], 'phone': '222222'}
# 26

# %%
student = {'name':'Shaurya', 'Age':25, 'course':['maths','se']}

print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name', 'Age', 'course'])
# dict_values(['Shaurya', 25, ['maths', 'se']])
# dict_items([('name', 'Shaurya'), ('Age', 25), ('course', ['maths', 'se'])])

# %%
student = {'name':'Shaurya', 'Age':25, 'course':['maths','se']}

for key,value in student.items():
  print(key,value)
# Out:
# name Shaurya
# Age 25
# course ['maths', 'se']

# %% [markdown]
# ### **Python 06**
# Conditionals and Booleans - If, Else, and Elif Statements

# %%
language = 'python'
if language == 'python':
  print('Condition was true')
elif language == 'Java':
  print('Language is java ')
else:
  print('No Match')
# Out:
# Condition was true

# %%
a = [1, 2, 3]
b = [1, 2, 3]

print(a == b)
print(a is b) # false, coz it compare address/id of two
c = a 
print(a is c)

print(id(a))
print(id(b))
print(id(c))
# Out:
# True
# False
# True
# 140046544233808
# 140046473482144
# 140046544233808

# %%
# False Values:
    # False
    # None
    # Zero of any numeric type
    # Any empty sequence. For example, '', (), [].
    # Any empty mapping. For example, {}.

condition = False

if condition:
    print('Evaluated to True')
else:
    print('Evaluated to False')
# Out:
# Evaluated to False

# %% [markdown]
# ### **Python 07**
# Loops and Iterations - For/While Loops

# %%
nums = [1,2,3]

for num in nums:
  print(num)

for i in range(1,3):
  print(i)
# cmd + c : termiate   
x = 0

while x < 3:
  print(x)
  x+=1
# Out:
# 1
# 2
# 3
# 1
# 2
# 0
# 1
# 2

# %% [markdown]
# ### **Python 08**
# Functions

# %%
  #function

  def hello_fun():
    print('hello function')
  def newFun():
    return 'hello function'
print(hello_fun())
# Out:
# hello function
# None

# %%
def hello_func(greeting, name ='shaurya'): #default value for name 
  return f'{greeting} Function, there is {name}'

print(hello_func('hey'))
# Out:
# hey Function, there is shaurya

# %%
def student_info(*args,**kwargs):
  print(args)
  print(kwargs)

student_info('Maths','Art',name='john',age=20)
# Out:
# ('Maths', 'Art')
# {'name': 'john', 'age': 20}

# %%
# Argunments as list , dict
def student_info(*args,**kwargs):
  print(args)
  print(kwargs)

courses = ['maths','art']
info = {'name':'John','age':22}

student_info(*courses,**info)
# Out:
# ('maths', 'art')
# {'name': 'John', 'age': 22}

# %%
# Number of days per month. First value placeholder for indexing purposes.
month_days = [0, 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]


def is_leap(year):
    """Return True for leap years, False for non-leap years."""

    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)


def days_in_month(year, month):
    """Return number of days in that month in that year."""

    if not 1 <= month <= 12:
        return 'Invalid Month'

    if month == 2 and is_leap(year):
        return 29

    return month_days[month]

# %% [markdown]
# ### **Python 09**
# Import Modules and Exploring The Standard Library

# %%
import numpy as mp #to import whole module
#from numpy import ____  #import only function from that modula
import sys
courses = ['SE','ADA','OT']
print(sys.path)
# Out:
# ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython']

# %%
# Out:
# Usage:
#   pip3 <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
# ...
